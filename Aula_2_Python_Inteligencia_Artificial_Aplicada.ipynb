# %% [markdown]
# <a href="https://colab.research.google.com/github/Ivan8Garcia/Proyectos_MachineLearning/blob/main/Aula_2_Python_Inteligencia_Artificial_Aplicada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Aula 2**

# %%
import os
from google.colab import userdata
os.environ["GEMINI_API_KEY"] = userdata.get("GEMINI_API_KEY")
# Out:
# ---------------------------------------------------------------------------
# SecretNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_4419/2702520540.py in <cell line: 0>()
#       1 import os
#       2 from google.colab import userdata
# ----> 3 os.environ["GEMINI_API_KEY"] = userdata.get("GEMINI_API_KEY")
#
# /usr/local/lib/python3.12/dist-packages/google/colab/userdata.py in get(key)
#      66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
# ---> 68     raise SecretNotFoundError(key)
#      69   if not resp.get('access', False):
#      70     raise NotebookAccessError(key)
#
# SecretNotFoundError: Secret GEMINI_API_KEY does not exist.

# %%
from google import genai

client = genai.Client()

# %%
respuesta = client.models.generate_content(model="gemini-2.5-flash", contents="Que es la IA")

# %%
print(respuesta.text)

# %%
print("*********************")

# %%
n = 1

while n <=100:
  print("*")
  n=n+1
print("Ya salimos del while")

# %%
chat = client.chats.create(model="gemini-2.5-flash")

# %%
respuesta = chat.send_message("Que es la IA")

# %%
print(respuesta)

# %%
respuesta =chat.send_message("Cuando se lanzo chatGPT")
print(respuesta.text)

# %%
chat.get_history()

# %%
prompt = input("Ingrese su pregunta: ")

while prompt != "fin":
  respuesta=chat.send_message(prompt)
  print(respuesta.text)
  prompt = input("Ingrese su pregunta (fin para terminar): ")

# %%
nombres = ["Juan","Laura","Fernando","Josefina","Pedro"]
# pos.       0       1         2          3        4
print(nombres)

# %%
print("El quinto elemento es:",nombres[4])

# %%
promedios = [8.5,6.5,7.3,9.5,6.3,2.5,4.8]
print(promedios[3])

# %%
n=0 #1

while n < len(promedios):
  promedios[n]=promedios[n]+1
  if promedios[n]>10:
     promedios[n]=10
  n=n+1
print("Los promedios mejorados son:",promedios)

# %%
print("Cantidad de elementos en la lista:",len(promedios))

# %%
promedios[-2]

# %%
nombres=["Maria Silva","Fernanda Castro","Juan Perez","Rodrigo Feliz","Juana Lala"]
print(nombres)

nombres[:3]
# Out:
# ['Maria Silva', 'Fernanda Castro', 'Juan Perez', 'Rodrigo Feliz', 'Juana Lala']
# ['Maria Silva', 'Fernanda Castro', 'Juan Perez']

# %%
nombres.append("Rogelio Rodriguez")
print(nombres)
# Out:
# ['Maria Silva', 'Fernanda Castro', 'Juan Perez', 'Rodrigo Feliz', 'Juana Lala', 'Rogelio Rodriguez']

# %%
print("Cantidad de elementos:",len(nombres))
# Out:
# Cantidad de elementos: 6

# %%
nombres.extend(["Mateo Perez","Laura Fernan"])
print(nombres)
# Out:
# ['Maria Silva', 'Fernanda Castro', 'Juan Perez', 'Rodrigo Feliz', 'Juana Lala', 'Rogelio Rodriguez', 'Mateo Perez', 'Laura Fernan']

# %%
nombres.append(["Juan Oroz","Pedro Pereyra"])

# %%
print(nombres)
# Out:
# ['Maria Silva', 'Fernanda Castro', 'Juan Perez', 'Rodrigo Feliz', 'Juana Lala', 'Rogelio Rodriguez', 'Mateo Perez', 'Laura Fernan', ['Juan Oroz', 'Pedro Pereyra']]

# %%
nombres[8][1]
# Out:
# 'Pedro Pereyra'

# %%
nombres[-1][-1]
# Out:
# 'Pedro Pereyra'

# %%
nombres.remove("Maria Silva")

# %%
nombres
# Out:
# ['Fernanda Castro',
#  'Juan Perez',
#  'Rodrigo Feliz',
#  'Juana Lala',
#  'Rogelio Rodriguez',
#  'Mateo Perez',
#  'Laura Fernan',
#  ['Juan Oroz', 'Pedro Pereyra']]

# %%
nombres.pop()
nombres
# Out:
# ['Fernanda Castro',
#  'Juan Perez',
#  'Rodrigo Feliz',
#  'Juana Lala',
#  'Rogelio Rodriguez',
#  'Mateo Perez',
#  'Laura Fernan']

# %%
nombres.pop(2)
nombres
# Out:
# ['Fernanda Castro',
#  'Juan Perez',
#  'Juana Lala',
#  'Rogelio Rodriguez',
#  'Mateo Perez',
#  'Laura Fernan']

# %% [markdown]
# Diccionarios:
#
# estudiantes=["clave":valor]

# %%
nombres=["Maria Silva","Fernanda Castro","Juan Perez","Rodrigo Feliz","Juana Lala"]
promedios = [8.5,6.5,7.3,9.5,6.3,2.5,4.8]

estudiantes = {
    "Maria Silva":8.5,
    "Fernanda Castro":6.5,
    "Juan Perez":7.3,
    "Rodrigo Feliz":6.3,
    "Juaan Lala":2.5
}

print(nombres)
print(promedios)
print(estudiantes)
# Out:
# ['Maria Silva', 'Fernanda Castro', 'Juan Perez', 'Rodrigo Feliz', 'Juana Lala']
# [8.5, 6.5, 7.3, 9.5, 6.3, 2.5, 4.8]
# {'Maria Silva': 8.5, 'Fernanda Castro': 6.5, 'Juan Perez': 7.3, 'Rodrigo Feliz': 6.3, 'Juaan Lala': 2.5}

# %%
print(estudiantes["Maria Silva"])
print(estudiantes.get("Maria Silva"))
# Out:
# 8.5
# 8.5

# %%
print(estudiantes.items())
# Out:
# dict_items([('Maria Silva', 8.5), ('Fernanda Castro', 6.5), ('Juan Perez', 7.3), ('Rodrigo Feliz', 6.3), ('Juaan Lala', 2.5)])

# %%
estudiantes.pop("Maria Silva")
estudiantes
# Out:
# {'Fernanda Castro': 6.5,
#  'Juan Perez': 7.3,
#  'Rodrigo Feliz': 6.3,
#  'Juaan Lala': 2.5}

# %%
print(estudiantes.keys())
# Out:
# dict_keys(['Fernanda Castro', 'Juan Perez', 'Rodrigo Feliz', 'Juaan Lala'])

# %%
print(estudiantes.values())
# Out:
# dict_values([6.5, 7.3, 6.3, 2.5])

# %%
persona= {
    "nombre":"Juan Perez",
    "edad":25,
    "materias":["Matematica","Literatura","Dibujo"]
}

print(persona)
# Out:
# {'nombre': 'Juan Perez', 'edad': 25, 'materias': ['Matematica', 'Literatura', 'Dibujo']}

# %%
estudiante1 = {
    "nombre":"Juan Perez","edad":25
    }

estudiante2 = {
    "nombre":"Laura Fernandez","edad":28
    }

print(estudiante1)
print(estudiante2)
# Out:
# {'nombre': 'Juan Perez', 'edad': 25}
# {'nombre': 'Laura Fernandez', 'edad': 28}

# %%
lista_de_estudiantes= [
    {
    "nombre":"Juan Perez","edad":25
    },
    {
    "nombre":"Laura Fernandez","edad":28
    }
]

print(lista_de_estudiantes)
# Out:
# [{'nombre': 'Juan Perez', 'edad': 25}, {'nombre': 'Laura Fernandez', 'edad': 28}]

# %%
lista_de_estudiantes[1]
# Out:
# {'nombre': 'Laura Fernandez', 'edad': 28}

# %%
lista_de_estudiantes[1]["edad"]
# Out:
# 28

# %%
lista_de_estudiantes= [
    {
    "nombre":"Juan Perez","edad":25
    },
    {
    "nombre":"Laura Fernandez","edad":28
    }
]

n=0

while n < len(lista_de_estudiantes):
  print(lista_de_estudiantes[n])
  n+=1

for elemento in lista_de_estudiantes:
  print(elemento)

print("con cantidad definida")
for n in range(5):
  print(n)

print("con rango definido")
for n in range(2,8):
  print(n)

print("con intervalos")
for n in range(2,8,2):
  print(n)
# Out:
# {'nombre': 'Juan Perez', 'edad': 25}
# {'nombre': 'Laura Fernandez', 'edad': 28}
# {'nombre': 'Juan Perez', 'edad': 25}
# {'nombre': 'Laura Fernandez', 'edad': 28}
# con cantidad definida
# 0
# 1
# 2
# 3
# 4
# con rango definido
# 2
# 3
# 4
# 5
# 6
# 7
# con intervalos
# 2
# 4
# 6

# %%
persona= {
    "nombre":"Juan Perez",
    "edad":25,
    "materias":["Matematica","Literatura","Dibujo"]
}

for clave,valor in persona.items():
  print(f"La clave es: {clave} y el valor es: {valor}")

for n in range(11):
  if n%2==0:
    print(n)
# Out:
# La clave es: nombre y el valor es: Juan Perez
# La clave es: edad y el valor es: 25
# La clave es: materias y el valor es: ['Matematica', 'Literatura', 'Dibujo']
# 0
# 2
# 4
# 6
# 8
# 10

# %%
texto = "martIN bonino  de alUra "

print("Texto original:", texto)

print(texto.upper())
print(texto.lower())
print(texto.strip())

print("Texto sin los espacios repetidos en el medio")
print(texto.replace("  ", " "))

print(texto)

print(texto.lower().strip().replace("  ", " "))
print(texto)

texto = texto.lower().strip().replace("  ", " ")

print(texto)

# %%
nombres_1 = "   jUAn  pErez   "
nombres_2 = "mArIA   gONzaleZ   "
nombres_3 = "   rOdRiGo   saNchEz "
nombres_4 = "  ElisAbEtH   fLoReS"

# %%
def corregir_texto(texto):
    texto_nuevo = texto.lower().strip().replace("  ", " ")
    print(texto_nuevo)

# %%
corregir_texto(" LaURA fernandez  ")
# Out:
# laura fernandez

# %%
corregir_texto(nombres_1)
corregir_texto(nombres_2)
corregir_texto(nombres_3)
corregir_texto(nombres_4)   #en este ejemplo el resultado sigue teniendo dos espacios sin corregir porque encontró 3espacios y no 2, asi que no lo corrigió
# Out:
# juan perez
# maria  gonzalez
# rodrigo  sanchez
# elisabeth  flores

# %%
nombres_1.split()
# Out:
# ['jUAn', 'pErez']

# %%
texto_corregido= " ".join(nombres_1.split())
print(texto_corregido)
# Out:
# jUAn pErez

# %%
def corregir_texto(texto):
    texto_nuevo = texto.upper()
    lista_texto=texto_nuevo.split()
    #print(lista_texto)      se comentó para ver el resultado mas limpio en la siguiente celula de codigo
    texto_final=" ".join(lista_texto)
    print(texto_final)

# %%
corregir_texto(nombres_1)
corregir_texto(nombres_2)
corregir_texto(nombres_3)
corregir_texto(nombres_4)
# Out:
# JUAN PEREZ
# MARIA GONZALEZ
# RODRIGO SANCHEZ
# ELISABETH FLORES

# %%
#SIMPLIFICACION DE CODIGO
def corregir_texto(texto):
    print(" ".join(texto.upper().split()))

# %%
corregir_texto(" LaURA fernandez  ")
# Out:
# LAURA FERNANDEZ

# %%
salones= ["Salón 1", "Salón 2", "Salón 3"]

# %%
import random

def ubica_alumnos(nombre_alumno, lista_salones):
    salon_asignado = random.choice(lista_salones)

    dict_alumnos = {
        "nombre": nombre_alumno,
        "salon": salon_asignado
    }

    print(dict_alumnos)

# %%
ubica_alumnos("Roberto Gonzalez",salones)
# Out:
# {'nombre': 'Roberto Gonzalez', 'salon': 'Salón 1'}

# %%
def corrije_texto(texto):
    texto_nuevo = texto.upper()
    lista_palabras = texto_nuevo.split()
    nombre_final = " ".join(lista_palabras)
    return nombre_final    #SE USA RETURN PARA PODER TRAER INFORMACION FUERA DE OTRAS FUNCIONES

# %%
nombre_optimizado = corrije_texto(nombres_2)
print(nombre_optimizado)

ubica_alumnos(nombre_optimizado, salones)
# Out:
# MARIA GONZALEZ
# {'nombre': 'MARIA GONZALEZ', 'salon': 'Salón 2'}

# %% [markdown]
# # **DESAFÍO**
#
# ##crear una funcion que va a recibir como argumento una lista de emails y le va a pedir a una IA que los resuma en una sola linea

# %%
cuerpos_emails = [
    "Hola, te envío el reporte de ventas del trimestre que solicitaste en la reunión. Quedo atento a tus comentarios.",
    "¡Tu suscripción ha sido renovada con éxito! El cargo de 9.99€ se ha aplicado a tu tarjeta terminada en 4421.",
    "¿Qué tal todo? Hace mucho que no hablamos. Podríamos quedar a tomar un café este jueves si tienes un hueco.",
    "¡URGENTE! Tu cuenta ha sido bloqueada temporalmente por actividad inusual. Haz clic aquí para verificar tu identidad.",
    "Estimado alumno, le recordamos que el plazo para la entrega del proyecto final finaliza este viernes a medianoche.",
    "Gracias por tu compra. Tu pedido #98234 ya está siendo preparado en nuestro almacén y saldrá hoy mismo.",
    "Oferta flash: Solo durante las próximas 2 horas, todos nuestros cursos de Python tienen un 80% de descuento.",
    "Hola equipo, el lunes la oficina permanecerá cerrada por festivo local. Disfrutad del fin de semana largo.",
    "Se ha detectado un inicio de sesión desde un nuevo navegador en Chrome (Windows). Si no has sido tú, cambia tu clave.",
    "Confirmamos tu reserva en El Restaurante El Olivo para 4 personas a las 21:30. ¡Te esperamos!",
    "Lamentamos informarle que su vuelo FR4521 ha sufrido un retraso de 45 minutos debido a causas meteorológicas.",
    "Hola, ¿podrías revisar el código que subí ayer a GitHub? Tengo dudas sobre si la función de validación es eficiente.",
    "Tu paquete ha sido entregado en el buzón o a un vecino. Por favor, verifica el punto de entrega.",
    "¡Felicidades! Has sido seleccionado para participar en nuestra fase beta cerrada. Descarga el instalador aquí.",
    "Hola mamá, llegamos bien al hotel. El viaje fue tranquilo y el sitio es precioso. Mañana te mando fotos.",
    "Estimado usuario, hemos actualizado nuestra política de cookies para cumplir con la nueva normativa europea.",
    "¿Te interesa ganar dinero extra rellenando encuestas? Únete a nuestra comunidad y empieza a sumar puntos hoy.",
    "Recordatorio: Tienes una cita pendiente con tu dentista mañana a las 11:00 am. Por favor, confirma asistencia.",
    "La reunión de comunidad de vecinos se traslada al portal B debido a las obras en el salón de actos principal.",
    "Hola, te adjunto las fotos del evento del sábado. Salieron muy bien, sobre todo la de la tarta. ¡Un saludo!"
]
